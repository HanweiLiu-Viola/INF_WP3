# %%
# %gui qt
# %load_ext autoreload
# %autoreload 2

# %%
import mne
mne.viz.set_browser_backend('qt')
mne.viz.set_3d_backend('pyvistaqt')
mne.set_config('MNE_DATA', '/workspace/shared/mne_data', set_env=True)
# Out:
# Using qt as 2D backend.
# Using pyvistaqt 3d backend.

# %%
import mne
from pathlib import Path

SAVE_DIR = Path('/workspace/shared/temp')
SUBJECTS_DIR = Path('/workspace/shared/data/mne_subjects')

raw_eeg = mne.io.read_raw_fif(SAVE_DIR / 'sub-001_eeg_clean.fif', preload=True)
raw_lfp = mne.io.read_raw_fif(SAVE_DIR / 'sub-001_lfp_clean.fif', preload=True)
# Out:
# Opening raw data file /workspace/shared/temp/sub-001_eeg_clean.fif...
#     Range : 0 ... 15000 =      0.000 ...    60.000 secs
# Ready.
# /tmp/ipykernel_110870/2088429917.py:7: RuntimeWarning: This filename (/workspace/shared/temp/sub-001_eeg_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_eeg = mne.io.read_raw_fif(SAVE_DIR / 'sub-001_eeg_clean.fif', preload=True)
# Reading 0 ... 15000  =      0.000 ...    60.000 secs...
# Opening raw data file /workspace/shared/temp/sub-001_lfp_clean.fif...
# Isotrak not found
#     Range : 0 ... 29686 =      0.000 ...   118.744 secs
# Ready.
# Reading 0 ... 29686  =      0.000 ...   118.744 secs...
# /tmp/ipykernel_110870/2088429917.py:8: RuntimeWarning: This filename (/workspace/shared/temp/sub-001_lfp_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_lfp = mne.io.read_raw_fif(SAVE_DIR / 'sub-001_lfp_clean.fif', preload=True)
